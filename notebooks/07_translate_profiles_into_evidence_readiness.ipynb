# %% [markdown]
# # Translate the analysis into evidence-ready claims
#
# **Data and method:** the validated benchmark, profile definitions, robustness evidence, external context and documented geography evidence.
#
# **Purpose:** inspect checksum-verified writing authorities that connect each proposed conclusion to its empirical source, cohort and language boundary.
#
# This is an evidence-inspection notebook. It does not rerun upstream external-source extraction or adjusted models.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))
CONFIG_PATH = ROOT / 'configs' / 'reference_apr2025_mar2026.json'
from gpap2.config import load_config
REFERENCE_CONFIG = load_config(CONFIG_PATH)
AUTHORITY_MANIFEST = REFERENCE_CONFIG.resolve(REFERENCE_CONFIG.authority_checksum_file)
import pandas as pd
pd.set_option('display.max_columns', 50)
pd.set_option('display.width', 120)
pd.set_option('display.precision', 6)

# %%
import pandas as pd
from gpap2.io import validate_authority_file

claims_path = ROOT / 'outputs' / 'tables' / 'claim_to_evidence_matrix.csv'
availability_path = ROOT / 'outputs' / 'tables' / 'evidence_availability_summary.csv'
validate_authority_file(claims_path, AUTHORITY_MANIFEST)
validate_authority_file(availability_path, AUTHORITY_MANIFEST)
claims = pd.read_csv(claims_path)
availability = pd.read_csv(availability_path)
pd.DataFrame({
    'authority': ['claim-to-evidence matrix', 'evidence-availability summary'],
    'rows': [len(claims), len(availability)],
})
# Out:
#                        authority  rows
# 0       claim-to-evidence matrix    42
# 1  evidence-availability summary    18

# %%
required_scientific_fields = {
    'claim_id',
    'primary_claim_domain',
    'exact_construct_observed',
    'support_category',
    'linked_table_figure',
    'source_lineage',
    'construct_evidence_link',
    'permitted_wording',
    'prohibited_wording',
}
assert required_scientific_fields.issubset(claims.columns)
assert len(claims) == 42 and claims['claim_id'].is_unique
claims[['claim_id', 'primary_claim_domain', 'proposed_claim', 'support_category', 'permitted_wording', 'prohibited_wording']].head(10)
# Out:
#   claim_id primary_claim_domain                                     proposed_claim  \
# 0      A01               ACCESS                  National OCS–GPAD profiles exist.
# 1      A02               ACCESS  Profiles are sufficiently stable for cautious ...
# 2      A03               ACCESS  Alternative algorithms recover related but non...
# 3      A04               ACCESS  Feature sensitivity supports a related, non-id...
# 4      A05               ACCESS  Temporal robustness supports the annual soluti...
# 5      A06               ACCESS  CBT inbound sensitivity produces a related pro...
# 6      A07               ACCESS  CBT outcome-complete sensitivity is compositio...
# 7      B01               ACCESS  OCS activity represents visible online-route a...
# 8      B02               ACCESS  GPAD represents recorded appointment activity ...
# 9      B03               ACCESS  CBT provides recorded telephone-route activity...
#
#                                  support_category                                  permitted_wording  \
# 0                         DESCRIPTIVELY_SUPPORTED  Three national practice-level recorded-activit...
# 1  PARTIALLY_SUPPORTABLE_WITH_MAJOR_QUALIFICATION  The profiles support cautious descriptive use ...
# 2                         DESCRIPTIVELY_SUPPORTED  Alternative algorithms recovered related but n...
# 3  PARTIALLY_SUPPORTABLE_WITH_MAJOR_QUALIFICATION  The reduced feature set recovered broadly rela...
# 4  PARTIALLY_SUPPORTABLE_WITH_MAJOR_QUALIFICATION  The annual profiles recur strongly within half...
# 5  PARTIALLY_SUPPORTABLE_WITH_MAJOR_QUALIFICATION  Adding CBT inbound indicators altered some ass...
# 6  PARTIALLY_SUPPORTABLE_WITH_MAJOR_QUALIFICATION  CBT outcome sensitivity depended on feature re...
# 7                         DESCRIPTIVELY_SUPPORTED  OCS measures visible recorded online-route act...
# 8                         DESCRIPTIVELY_SUPPORTED  GPAD measures recorded appointment activity an...
# 9  PARTIALLY_SUPPORTABLE_WITH_MAJOR_QUALIFICATION  CBT provides recorded telephone-route activity...
#
#                                   prohibited_wording
# 0  The profiles are performance tiers or direct m...
# 1  The profiles are definitive, permanent or equa...
# 2  Alternative algorithms reproduced identical me...
# 3        Feature choice had no effect on membership.
# 4  Every practice retained the same profile throu...
# 5  CBT sensitivity represents all English practic...
# 6  CBT outcomes produce a unique national profile...
# 7  OCS submissions equal total demand, successful...
# 8  GPAD measures total demand or time from first ...
# 9  CBT measures total telephone pressure or repre...

# %% [markdown]
# ## Decision
#
# The evidence supports descriptive practice-level activity profiles, bounded robustness results and contextual associations. Linked pathway, outcome, safety, cost and implementation evidence is required before extending those results to causal or patient-level claims.

# %% [markdown]
# **What this establishes:** the 42-claim authority defines the evidence that may be reported and the interpretations that require additional data.
